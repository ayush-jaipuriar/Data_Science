# %%
import pandas as pd
import numpy as np
summer = pd.read_csv(r'/home/ayush/Documents/Python/Python Exercise/original_2/Course_Materials_Part2/Video_Lecture_NBs/summer.csv')
titanic = pd.read_csv(r'/home/ayush/Documents/Python/Python Exercise/original_2/Course_Materials_Part2/Video_Lecture_NBs/titanic.csv')

# %%
summer
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# ...

# %%
sample = summer.sample(n=7, random_state = 123).sort_values('Year')

# %%
sample
# Out:
#        Year       City      Sport  Discipline                   Athlete  \
# 4196   1924      Paris   Aquatics  Water polo            AUSTIN, Arthur
# 11961  1968     Mexico  Athletics   Athletics  FOSBURY, Richard Douglas
# 11742  1968     Mexico   Aquatics    Swimming   WENDEN, Michael Vincent
# 13996  1976   Montreal   Aquatics    Swimming          MAC DONALD, Gary
# 16229  1980     Moscow     Rowing      Rowing       DMITRIENKO, Grigori
# 19728  1992  Barcelona   Aquatics    Swimming        KULIKOV, Vladislav
# 25901  2004     Athens     Boxing      Boxing            YELEUOV, Serik
#
#       Country Gender                     Event   Medal
# 4196      USA    Men                Water Polo  Bronze
# 11961     USA    Men                 High Jump    Gold
# 11742     AUS    Men            200M Freestyle    Gold
# 13996     CAN    Men       4X100M Medley Relay  Silver
# 16229     URS    Men  Eight With Coxswain (8+)  Bronze
# 19728     EUN    Men       4X100M Medley Relay  Silver
# ...

# %%
city_country =  {'Paris':'France', 'Mexico':'Mexico', 'Montreal':'Canada', 'Moscow':'Russia', 'Barcelona':'Spain', 'Athens':'Greece' }

# %%
sample['City'].map(city_country)
# Out:
# 4196     France
# 11961    Mexico
# 11742    Mexico
# 13996    Canada
# 16229    Russia
# 19728     Spain
# 25901    Greece
# Name: City, dtype: object

# %%
sample['Host_Country'] = sample['City'].map(city_country)

# %%
sample
# Out:
#        Year       City      Sport  Discipline                   Athlete  \
# 4196   1924      Paris   Aquatics  Water polo            AUSTIN, Arthur
# 11961  1968     Mexico  Athletics   Athletics  FOSBURY, Richard Douglas
# 11742  1968     Mexico   Aquatics    Swimming   WENDEN, Michael Vincent
# 13996  1976   Montreal   Aquatics    Swimming          MAC DONALD, Gary
# 16229  1980     Moscow     Rowing      Rowing       DMITRIENKO, Grigori
# 19728  1992  Barcelona   Aquatics    Swimming        KULIKOV, Vladislav
# 25901  2004     Athens     Boxing      Boxing            YELEUOV, Serik
#
#       Country Gender                     Event   Medal Host_Country
# 4196      USA    Men                Water Polo  Bronze       France
# 11961     USA    Men                 High Jump    Gold       Mexico
# 11742     AUS    Men            200M Freestyle    Gold       Mexico
# 13996     CAN    Men       4X100M Medley Relay  Silver       Canada
# ...

# %% [markdown]
# titanic

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
titanic['pclass']
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: pclass, Length: 891, dtype: int64

# %%
class_name = {1:'first', 2:'second', 3:'third'}

# %%
titanic['Class_Name'] = titanic['pclass'].map(class_name)

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck  \
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
#     Class_Name
# 0        third
# 1        first
# 2        third
# 3        first
# ...

# %%
titanic['no_of_relatives'] = titanic['sibsp'].add(titanic['parch'], fill_value = 0)

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck  \
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
#     Class_Name  no_of_relatives
# 0        third                1
# ...

# %%
titanic['alone'] = np.where(titanic['no_of_relatives']==0, 'Yes', 'No')

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck  \
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
#     Class_Name  no_of_relatives alone
# 0        third                1    No
# ...

# %%
 titanic['child'] = pd.Series(np.where(titanic['age']<=10, 'Yes', 'No'))

# %%
titanic[titanic['child']=='Yes'].survived.plot.

# %%
age_bins = [0,10,18,35,55,100]

# %%
cat = pd.cut(titanic['age'], age_bins, right=False)

# %%
titanic['age_bracket'] = cat

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck  \
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
#     Class_Name  no_of_relatives alone child   age_bracket
# ...

# %%
titanic['age_bracket'].value_counts()
# Out:
# [18, 35)     366
# [35, 55)     193
# [0, 10)       62
# [10, 18)      51
# [55, 100)     42
# Name: age_bracket, dtype: int64

# %%
titanic.groupby('age_bracket')['survived'].mean()
# Out:
# age_bracket
# [0, 10)      0.612903
# [10, 18)     0.450980
# [18, 35)     0.368852
# [35, 55)     0.419689
# [55, 100)    0.309524
# Name: survived, dtype: float64

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck  \
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
#     Class_Name  no_of_relatives alone child   age_bracket
# ...

# %%
group_names = ['child', 'teen', 'young adult', 'adult', 'elderly']

# %%
titanic['age_cat'] = pd.cut(titanic['age'], age_bins, right= False, labels = group_names)

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck  \
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
#     Class_Name  no_of_relatives alone child   age_bracket      age_cat
# ...

# %%
titanic['fare'].describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: fare, dtype: float64

# %%
titanic['fare'].plot.box()

# %%
fare_group = [0,50,100,200,250,600]

# %%
financial_health = pd.cut(titanic['fare'], fare_group)

# %%
titanic['financial_health'] = financial_health

# %%
titanic['financial_health'].value_counts()
# Out:
# (0, 50]       716
# (50, 100]     107
# (100, 200]     33
# (200, 250]     11
# (250, 600]      9
# Name: financial_health, dtype: int64

# %%
titanic.groupby('financial_health')['survived'].mean().plot.bar()

# %%
finance = ['Poor', 'Lower Middle Class', 'Upper Middle Class', 'Rich', 'Ultra Rich']

# %%
financial_health = pd.cut(titanic['fare'], fare_group, labels = finance)

# %%
titanic['financial_health'] = financial_health

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck  \
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
#     Class_Name  no_of_relatives alone child   age_bracket      age_cat  \
# ...

# %%
titanic['fare'].describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: fare, dtype: float64

# %%
titanic['fare'].plot()

# %%
titanic['fare'].sort_values(ascending=False)
# Out:
# 679    512.3292
# 258    512.3292
# 737    512.3292
# 341    263.0000
# 438    263.0000
#          ...
# 277      0.0000
# 633      0.0000
# 302      0.0000
# 597      0.0000
# 271      0.0000
# Name: fare, Length: 891, dtype: float64

# %%
fare_cap = 250
titanic.loc[titanic['fare']>fare_cap, 'fare'] = fare_cap

# %%
titanic['fare'].plot()

# %%
titanic['fare'].sort_values(ascending=True).head(10)
# Out:
# 271    0.0
# 597    0.0
# 302    0.0
# 633    0.0
# 277    0.0
# 413    0.0
# 674    0.0
# 263    0.0
# 466    0.0
# 732    0.0
# Name: fare, dtype: float64

# %%
titanic[titanic['fare']<5]['fare'].value_counts()
# Out:
# 0.0000    15
# 4.0125     1
# Name: fare, dtype: int64

# %%
fare_floor = 5
titanic.loc[titanic['fare']<fare_floor, 'fare'] = fare_floor

# %%
titanic['fare'].plot.box()
